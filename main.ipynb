# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/Ma-Bichette/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Projects/Ma Bichette/data/Lesson-Ma-Bichette.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/openpyxl/reader/excel.py in read(self)
#     300             action = "read stylesheet"
# --> 301             apply_stylesheet(self.archive, self.wb)
#     302             action = "read worksheets"
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py in apply_stylesheet(archive, wb)
#     208     node = fromstring(src)
# --> 209     stylesheet = Stylesheet.from_tree(node)
#     210
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py in from_tree(cls, node)
#     104             del node.attrib[k]
# --> 105         return super().from_tree(node)
#     106
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/descriptors/serialisable.py in from_tree(cls, node)
#      82                 #descriptor manages conversion
# ...
